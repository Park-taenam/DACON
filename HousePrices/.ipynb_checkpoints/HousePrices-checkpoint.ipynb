# %% [markdown]
# # 집값  예측 경진대회
# - https://dacon.io/competitions/official/235869/overview/description
#
# > Feature
# - id : 데이터 고유 id
# - OverallQual : 전반적 재료와 마감 품질
# - YearBuilt : 완공 연도
# - YearRemodAdd : 리모델링 연도
# - ExterQual : 외관 재료 품질
# - BsmtQual : 지하실 높이
# - TotalBsmtSF : 지하실 면적
# - 1stFlrSF : 1층 면적
# - GrLivArea : 지상층 생활 면적
# - FullBath : 지상층 화장실 개수
# - KitchenQual : 부억 품질
# - GarageYrBlt : 차고 완공 연도
# - GarageCars: 차고 자리 개수
# - GarageArea: 차고 면적
#
# > Target
# - target : 집값(달러 단위)

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('precision', 2)

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
matplotlib.rc('figure', facecolor='w', edgecolor='w')

# %% [markdown]
# # DataSet

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

# %%
df_train.drop(['id'], axis=1, inplace=True)
df_test.drop(['id'], axis=1, inplace=True)

# %%
print("Train data's shape : {}".format(df_train.shape))
print("Test data's shape : {}".format(df_test.shape))
# Out:
# Train data's shape : (1350, 14)
# Test data's shape : (1350, 13)

# %%
# Null 값 전혀 없음
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Overall Qual    1350 non-null   int64
#  1   Gr Liv Area     1350 non-null   int64
#  2   Exter Qual      1350 non-null   object
#  3   Garage Cars     1350 non-null   int64
#  4   Garage Area     1350 non-null   int64
#  5   Kitchen Qual    1350 non-null   object
#  6   Total Bsmt SF   1350 non-null   int64
#  7   1st Flr SF      1350 non-null   int64
#  8   Bsmt Qual       1350 non-null   object
#  9   Full Bath       1350 non-null   int64
#  10  Year Built      1350 non-null   int64
#  11  Year Remod/Add  1350 non-null   int64
#  12  Garage Yr Blt   1350 non-null   int64
#  13  target          1350 non-null   int64
# dtypes: int64(11), object(3)
# memory usage: 147.8+ KB

# %%
df_train.head()
# Out:
#    Overall Qual  Gr Liv Area Exter Qual  Garage Cars  Garage Area  \
# 0            10         2392         Ex            3          968
# 1             7         1352         Gd            2          466
# 2             5          900         TA            1          288
# 3             5         1174         TA            2          576
# 4             7         1958         Gd            3          936
#
#   Kitchen Qual  Total Bsmt SF  1st Flr SF Bsmt Qual  Full Bath  Year Built  \
# 0           Ex           2392        2392        Ex          2        2003
# 1           Gd           1352        1352        Ex          2        2006
# 2           TA            864         900        TA          1        1967
# 3           Gd            680         680        TA          1        1900
# 4           Gd           1026        1026        Gd          2        2005
#
#    Year Remod/Add  Garage Yr Blt  target
# 0            2003           2003  386250
# 1            2007           2006  194000
# 2            1967           1967  123000
# 3            2006           2000  135000
# 4            2005           2005  250000

# %%
df_train.describe()
# Out:
#        Overall Qual  Gr Liv Area  Garage Cars  Garage Area  Total Bsmt SF  \
# count       1350.00      1350.00      1350.00      1350.00        1350.00
# mean           6.21      1513.54         1.87       502.01        1082.64
# std            1.34       487.52         0.65       191.39         384.07
# min            2.00       480.00         1.00       100.00         105.00
# 25%            5.00      1144.00         1.00       368.00         816.00
# 50%            6.00      1445.50         2.00       484.00        1009.00
# 75%            7.00      1774.50         2.00       588.00        1309.50
# max           10.00      4476.00         5.00      1488.00        2660.00
#
#        1st Flr SF  Full Bath  Year Built  Year Remod/Add  Garage Yr Blt  \
# count     1350.00    1350.00     1350.00         1350.00        1350.00
# mean      1167.47       1.56     1972.99         1985.10        1978.47
# std        375.06       0.55       29.31           20.15          25.38
# min        480.00       0.00     1880.00         1950.00        1900.00
# 25%        886.25       1.00     1955.00         1968.00        1961.00
# 50%       1092.50       2.00     1976.00         1993.00        1978.50
# 75%       1396.50       2.00     2002.00         2004.00        2002.00
# max       2898.00       4.00     2010.00         2010.00        2207.00
#
#           target
# count    1350.00
# mean   186406.31
# std     78435.42
# min     12789.00
# 25%    135000.00
# 50%    165375.00
# 75%    217875.00
# max    745000.00

# %% [markdown]
# # EDA

# %% [markdown]
# ## Target
#
# > 정보
# - 좌측으로 편향되어 보임 -> log transformation 적용
# - log transformation 했을 때 엄청 작은 값 있음. (10.5 3.3.11에서 제거!)

# %%
target = df_train['target']

# %%
target.describe()
# Out:
# count      1350.00
# mean     186406.31
# std       78435.42
# min       12789.00
# 25%      135000.00
# 50%      165375.00
# 75%      217875.00
# max      745000.00
# Name: target, dtype: float64

# %%
plt.figure(figsize=(14,14))

plt.subplot(2,2,1)
plt.hist(target)
plt.title('Histogram - target', fontdict={'fontsize':20})
plt.ylabel('Count')

plt.subplot(2,2,2)
plt.boxplot(target)
plt.title('Boxplot - target', fontdict={'fontsize':20})

plt.subplot(2,2,3)
sns.kdeplot(target)
plt.title('KDE - target', fontdict={'fontsize':20})

plt.subplot(2,2,4)
sns.distplot(target,
                   color='b',
                   label='Skewness : {:.2f}'.format(target.skew()))
plt.legend(loc='best')
plt.title('Distplot - target', fontdict={'fontsize':20})

plt.show()

# %%
np.log1p(df_train['target'])
# Out:
# 0       12.86
# 1       12.18
# 2       11.72
# 3       11.81
# 4       12.43
#         ...
# 1345    12.23
# 1346    12.87
# 1347    11.87
# 1348    11.78
# 1349    11.85
# Name: target, Length: 1350, dtype: float64

# %%
# log transformation
plt.figure(figsize=(14,14))

plt.subplot(2,2,1)
plt.hist(np.log1p(df_train['target']))
plt.title('Histogram - log(target)', fontdict={'fontsize':20})
plt.ylabel('Count')

plt.subplot(2,2,2)
plt.boxplot(np.log1p(df_train['target']))
plt.title('Boxplot - log(target)', fontdict={'fontsize':20})

plt.subplot(2,2,3)
sns.kdeplot(np.log1p(df_train['target']))
plt.title('KDE - log(target)', fontdict={'fontsize':20})

plt.subplot(2,2,4)
sns.distplot(np.log1p(df_train['target']),
             color='b',
             label='Skewness : {:.2f}'.format(np.log1p(df_train['target']).skew()))
plt.legend(loc='best')
plt.title('Distplot - log(target)', fontdict={'fontsize':20})

plt.show()

# %% [markdown]
# ## Feature - type으로 분류

# %%
numerical_feature =  df_train.columns[df_train.dtypes!=object][:-1] # target 제외
categorical_feature = df_train.columns[df_train.dtypes==object]

print('수치형 데이터 : {}'.format(list(numerical_feature)))
print('카테고리형 데이터 : {}'.format(list(categorical_feature)))
# Out:
# 수치형 데이터 : ['Overall Qual', 'Gr Liv Area', 'Garage Cars', 'Garage Area', 'Total Bsmt SF', '1st Flr SF', 'Full Bath', 'Year Built', 'Year Remod/Add', 'Garage Yr Blt']
# 카테고리형 데이터 : ['Exter Qual', 'Kitchen Qual', 'Bsmt Qual']

# %% [markdown]
# ## Numerical Features

# %% [markdown]
# ### Overall Qual
#
# > 전반적 재료와 마감 품질
# - 다른 Qual Feature들과 비교해서 차원 축소 고려

# %%
df_train['Overall Qual'].head()
# Out:
# 0    10
# 1     7
# 2     5
# 3     5
# 4     7
# Name: Overall Qual, dtype: int64

# %%
df_train['Overall Qual'].value_counts().sort_index()
# Out:
# 2       3
# 3       8
# 4      75
# 5     379
# 6     351
# 7     307
# 8     156
# 9      56
# 10     15
# Name: Overall Qual, dtype: int64

# %%
fig,ax = plt.subplots(1,1,figsize=(7,7))
sns.countplot(x="Overall Qual", data=df_train)
plt.show()

# %% [markdown]
# ### Gr Liv Area
#
# > 지상층 생활 면적
# - 왼쪽으로 편향되어 보임 -> log Transformation

# %%
df_train['Gr Liv Area'].head()
# Out:
# 0    2392
# 1    1352
# 2     900
# 3    1174
# 4    1958
# Name: Gr Liv Area, dtype: int64

# %%
df_train['Gr Liv Area'].describe()
# Out:
# count    1350.00
# mean     1513.54
# std       487.52
# min       480.00
# 25%      1144.00
# 50%      1445.50
# 75%      1774.50
# max      4476.00
# Name: Gr Liv Area, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.boxplot(df_train['Gr Liv Area'])
plt.title('Boxplot - Gr Liv Area', fontdict={'fontsize':20})

plt.subplot(1,2,2)
sns.distplot(df_train['Gr Liv Area'], color='b', label='Skewness : {:.2f}'.format(df_train['Gr Liv Area'].skew()))
plt.legend(loc='best')
plt.title('Distplot - Gr Liv Area', fontdict={'fontsize':20})

plt.show()

# %%
# log transformation
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.boxplot(np.log1p(df_train['Gr Liv Area']))
plt.title('Boxplot - log1p(Gr Liv Area)', fontdict={'fontsize':20})

plt.subplot(1,2,2)
sns.distplot(np.log1p(df_train['Gr Liv Area']), color='b', label='Skewness : {:.2f}'.format(np.log1p(df_train['Gr Liv Area']).skew()))
plt.legend(loc='best')
plt.title('Distplot - log1p(Gr Liv Area)', fontdict={'fontsize':20})

plt.show()

# %% [markdown]
# ### Garage Cars
#
# > 차고 자리 개수

# %%
df_train['Garage Cars'].head()
# Out:
# 0    3
# 1    2
# 2    1
# 3    2
# 4    3
# Name: Garage Cars, dtype: int64

# %%
df_train['Garage Cars'].value_counts()
# Out:
# 2    794
# 1    372
# 3    172
# 4     11
# 5      1
# Name: Garage Cars, dtype: int64

# %%
fig,ax = plt.subplots(1,1,figsize=(7,7))
sns.countplot(x="Garage Cars", data=df_train)
plt.show()

# %% [markdown]
# ### Garage Area
#
# > 차고 면적
# - 왼쪽으로 편향되어 보임 -> log transformation

# %%
df_train['Garage Area'].head()
# Out:
# 0    968
# 1    466
# 2    288
# 3    576
# 4    936
# Name: Garage Area, dtype: int64

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.boxplot(df_train['Garage Area'])
plt.title('Boxplot - Garage Area', fontdict={'fontsize':20})

plt.subplot(1,2,2)
sns.distplot(df_train['Garage Area'], color='b', label='Skewness : {:.2f}'.format(df_train['Garage Area'].skew()))
plt.legend(loc='best')
plt.title('Distplot - Garage Area', fontdict={'fontsize':20})

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.boxplot(np.log1p(df_train['Garage Area']))
plt.title('Boxplot - log1p(Garage Area)', fontdict={'fontsize':20})

plt.subplot(1,2,2)
sns.distplot(np.log1p(df_train['Garage Area']), color='b', label='Skewness : {:.2f}'.format(np.log1p(df_train['Garage Area']).skew()))
plt.legend(loc='best')
plt.title('Distplot - log1p(Garage Area)', fontdict={'fontsize':20})

plt.show()

# %% [markdown]
# ### Total Bsmt SF
#
# > 지하실 면적
# - 편향되어 보임 -> 어떤 transformation이 좋은지 모르겠음

# %%
df_train['Total Bsmt SF'].head()
# Out:
# 0    2392
# 1    1352
# 2     864
# 3     680
# 4    1026
# Name: Total Bsmt SF, dtype: int64

# %%
pd.DataFrame(df_train['Total Bsmt SF'].describe())
# Out:
#        Total Bsmt SF
# count        1350.00
# mean         1082.64
# std           384.07
# min           105.00
# 25%           816.00
# 50%          1009.00
# 75%          1309.50
# max          2660.00

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.boxplot(df_train['Total Bsmt SF'])
plt.title('Boxplot - Total Bsmt SF', fontdict={'fontsize':20})

plt.subplot(1,2,2)
sns.distplot(df_train['Total Bsmt SF'], color='b', label='Skewness : {:.2f}'.format(df_train['Total Bsmt SF'].skew()))
plt.legend(loc='best')
plt.title('Distplot - Total Bsmt SF', fontdict={'fontsize':20})

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.boxplot(np.log1p(df_train['Total Bsmt SF']))
plt.title('Boxplot - log1p(Total Bsmt SF)', fontdict={'fontsize':20})

plt.subplot(1,2,2)
sns.distplot(np.log1p(df_train['Total Bsmt SF']), color='b', label='Skewness : {:.2f}'.format(np.log1p(df_train['Total Bsmt SF'].skew())))
plt.legend(loc='best')
plt.title('Distplot - log1p(Total Bsmt SF)', fontdict={'fontsize':20})

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.boxplot(np.sqrt(df_train['Total Bsmt SF']))
plt.title('Boxplot - sqrt(Total Bsmt SF)', fontdict={'fontsize':20})

plt.subplot(1,2,2)
sns.distplot(np.sqrt(df_train['Total Bsmt SF']), color='b', label='Skewness : {:.2f}'.format(np.sqrt(df_train['Total Bsmt SF'].skew())))
plt.legend(loc='best')
plt.title('Distplot - sqrt(Total Bsmt SF)', fontdict={'fontsize':20})

plt.show()

# %% [markdown]
# ### 1st Flr SF
#
# > 1층 면적
# - 왼쪽으로 편향 -> log transformation

# %%
df_train['1st Flr SF'].head()
# Out:
# 0    2392
# 1    1352
# 2     900
# 3     680
# 4    1026
# Name: 1st Flr SF, dtype: int64

# %%
pd.DataFrame(df_train['1st Flr SF'].describe())
# Out:
#        1st Flr SF
# count     1350.00
# mean      1167.47
# std        375.06
# min        480.00
# 25%        886.25
# 50%       1092.50
# 75%       1396.50
# max       2898.00

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.boxplot(df_train['1st Flr SF'])
plt.title('Boxplot - 1st Flr SF', fontdict={'fontsize':20})

plt.subplot(1,2,2)
sns.distplot(df_train['1st Flr SF'], color='b', label='Skewness : {:.2f}'.format(df_train['1st Flr SF'].skew()))
plt.legend(loc='best')
plt.title('Distplot - 1st Flr SF', fontdict={'fontsize':20})

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.boxplot(np.log1p(df_train['1st Flr SF']))
plt.title('Boxplot - log1p(1st Flr SF)', fontdict={'fontsize':20})

plt.subplot(1,2,2)
sns.distplot(np.log1p(df_train['1st Flr SF']), color='b', label='Skewness : {:.2f}'.format(np.log1p(df_train['1st Flr SF']).skew()))
plt.legend(loc='best')
plt.title('Distplot - log1p(1st Flr SF)', fontdict={'fontsize':20})

plt.show()

# %% [markdown]
# ### Full Bath
#
# > 지상층 화장실 개수

# %%
df_train['Full Bath'].head()
# Out:
# 0    2
# 1    2
# 2    1
# 3    1
# 4    2
# Name: Full Bath, dtype: int64

# %%
fig,ax = plt.subplots(1,1,figsize=(10,6))
sns.countplot(x="Full Bath", data=df_train)
plt.show()

# %% [markdown]
# ### Year Built
#
# > 완공 연도

# %%
df_train['Year Built'].head()
# Out:
# 0    2003
# 1    2006
# 2    1967
# 3    1900
# 4    2005
# Name: Year Built, dtype: int64

# %%
fig,ax = plt.subplots(1,1,figsize=(10,6))
sns.countplot(x="Year Built", data=df_train)
plt.show()

# %% [markdown]
# ### Year Remod/Add
#
# > 리모델링 연도

# %%
df_train['Year Remod/Add'].head()
# Out:
# 0    2003
# 1    2007
# 2    1967
# 3    2006
# 4    2005
# Name: Year Remod/Add, dtype: int64

# %%
fig,ax = plt.subplots(1,1,figsize=(10,6))
sns.countplot(x="Year Remod/Add", data=df_train)
plt.show()

# %% [markdown]
# ### Garage Yr Blt
#
# > 차고 완공 연도

# %%
df_train['Garage Yr Blt'].head()
# Out:
# 0    2003
# 1    2006
# 2    1967
# 3    2000
# 4    2005
# Name: Garage Yr Blt, dtype: int64

# %%
df_train['Garage Yr Blt'].value_counts()
# Out:
# 2005    70
# 2006    53
# 2007    51
# 2004    50
# 2003    49
#         ..
# 1924     1
# 1929     1
# 1931     1
# 1943     1
# 2207     1
# Name: Garage Yr Blt, Length: 97, dtype: int64

# %%
fig,ax = plt.subplots(1,1,figsize=(10,6))
sns.countplot(x="Garage Yr Blt", data=df_train)
plt.show()

# %%
# 잘 못 기재된 듯 -> 삭제!
df_train[df_train['Garage Yr Blt'] >= 2100].index
# Out:
# Int64Index([254], dtype='int64')

# %%
df_train.drop(df_train[df_train['Garage Yr Blt'] >= 2100].index, axis=0, inplace=True)

# %% [markdown]
# ### With target
#
# - log1p(target)가 10.5 이하면 제거 : 이상치

# %%
df_train.drop(df_train[np.log1p(df_train['target']) <= 10.5].index, axis=0, inplace=True)

# %%
feature = numerical_feature
target = 'target'

plt.figure(figsize=(18,12))
plt.suptitle("Scatter Plot", fontsize=40)

for i in range(len(feature)):
    plt.subplot(3,4,i+1)
    plt.xlabel(feature[i], fontsize=12)
    plt.ylabel(target, fontsize=10)
    corr_score = df_train[[feature[i],target]].corr().iloc[0,1].round(2)
    c = 'red' if corr_score>0 else 'blue'
    plt.scatter(df_train[feature[i]], df_train[target], color=c, label='corr={}'.format(corr_score))
    plt.legend(fontsize=15)
    
plt.tight_layout(rect=[0,0.03,1,0.95])
plt.show()

# %% [markdown]
# ## Categorical Features
#
# > Quality
# - Ex : 	Excellent
# - Gd :	Good
# - TA : 	Average/Typical
# - Fa :	Fair
# - Po :	Poor

# %% [markdown]
# ### Exter Qual
#
# > 외관 재료 품질

# %%
df_train['Exter Qual'].value_counts()
# Out:
# TA    806
# Gd    484
# Ex     49
# Fa      8
# Name: Exter Qual, dtype: int64

# %%
fig,ax = plt.subplots(1,1,figsize=(10,6))
sns.countplot(x="Exter Qual", data=df_train)
plt.show()

# %% [markdown]
# ### Kitchen Qual
#
# > 부억 품질

# %%
df_train['Kitchen Qual'].value_counts()
# Out:
# TA    658
# Gd    560
# Ex    106
# Fa     23
# Name: Kitchen Qual, dtype: int64

# %%
fig,ax = plt.subplots(1,1,figsize=(10,6))
sns.countplot(x="Kitchen Qual", data=df_train)
plt.show()

# %% [markdown]
# ### Bsmt Qual
#
# > 지하실 높이

# %%
df_train['Bsmt Qual'].value_counts()
# Out:
# TA    604
# Gd    581
# Ex    134
# Fa     27
# Po      1
# Name: Bsmt Qual, dtype: int64

# %%
df_train[df_train['Bsmt Qual'] == "Po"]
# Out:
#     Overall Qual  Gr Liv Area Exter Qual  Garage Cars  Garage Area  \
# 65             4         1049         TA            1          195
#
#    Kitchen Qual  Total Bsmt SF  1st Flr SF Bsmt Qual  Full Bath  Year Built  \
# 65           TA            356         671        Po          1        1910
#
#     Year Remod/Add  Garage Yr Blt  target
# 65            2000           1910   80900

# %%
fig,ax = plt.subplots(1,1,figsize=(10,6))
sns.countplot(x="Bsmt Qual", data=df_train)
plt.show()

# %% [markdown]
# ### With target

# %%
categorical_feature
# Out:
# Index(['Exter Qual', 'Kitchen Qual', 'Bsmt Qual'], dtype='object')

# %%
plt.figure(figsize=(6,6))
sns.catplot(x='Exter Qual', y=target, data=df_train)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.catplot(x='Kitchen Qual', y=target, data=df_train)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.catplot(x='Bsmt Qual', y=target, data=df_train)
plt.show()

# %% [markdown]
# # Feature Engineering
#
# - Feature들 상관관계 확인
# - Feature 줄이거나 관계있는 Feature들 합치거나 새로운 피쳐 생성
# - 편향된 Feature -> transformation

# %% [markdown]
# ## Feature

# %%
#년도와 관련된 변수 2022-변수로 바꿔주기
df_train['Year Built']=2022-df_train['Year Built']
df_train['Year Remod/Add']=2022-df_train['Year Remod/Add']
df_train['Garage Yr Blt']=2022-df_train['Garage Yr Blt']
df_test['Year Built']=2022-df_test['Year Built']
df_test['Year Remod/Add']=2022-df_test['Year Remod/Add']
df_test['Garage Yr Blt']=2022-df_test['Garage Yr Blt']

# %% [markdown]
# ## Transformation
#
# > log Transformation
# - target
# - Gr Liv Area
# - Garage Area
# - 1st Flr SF

# %%
df_train['target'] = np.log1p(df_train['target'])

logtr = ['Gr Liv Area', 'Garage Area', '1st Flr SF']

for i in range(len(logtr)):
    df_train[logtr[i]] = np.log1p(df_train[logtr[i]])
    df_test[logtr[i]] = np.log1p(df_test[logtr[i]])

# %% [markdown]
# ## Correlation

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# 상관계수 계산을 위해 텍스트 형식의 데이터를 숫자로 변환

corr_df = df_train.copy()
corr_df[categorical_feature] = corr_df[categorical_feature].astype(str).apply(LabelEncoder().fit_transform)

# %%
# 상관관계 분석도
plt.figure(figsize=(14,7))

heat_table = corr_df.corr()
mask = np.zeros_like(heat_table)
mask[np.triu_indices_from(mask)] = True

heatmap_ax = sns.heatmap(heat_table, annot=True, mask=mask, cmap='coolwarm')
heatmap_ax.set_xticklabels(heatmap_ax.get_xticklabels(), fontsize=15, rotation=45)
heatmap_ax.set_yticklabels(heatmap_ax.get_yticklabels(), fontsize=15)
plt.title("correlation between features", fontsize=40)

plt.show()

# %% [markdown]
# ## One-hot Encoding

# %%
df_train = pd.get_dummies(df_train)
df_test = pd.get_dummies(df_test)

# %%
# df_test에는 df_train과 다르게 'Kitchen Qual_Po' 가 있음 -> 우선 제거
df_test.drop(['Kitchen Qual_Po'], axis=1, inplace=True)

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.model_selection import KFold, RepeatedKFold, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# %%
def NMAE(true, pred):
    mae = np.mean(np.abs(true-pred))
    score = mae / np.mean(np.abs(true))
    return score

# %%
X_train = df_train.drop('target', axis=1).values
target = df_train['target'].values

X_test = df_test.values

# %%
print(target.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1347,)
# (1347, 23)
# (1350, 23)

# %%
# cross_val_score
import sklearn
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'v_measure_score']

# %%
model_scores = {}

# %% [markdown]
# ## LinearRegression

# %%
# 회귀라 r2 사용 -> default : r2
lr = LinearRegression()
score = cross_val_score(lr, X_train, target, cv=5, scoring ='r2')
print('cross validation score : {}'.format(score))
print('scores mean : {:.4f}'.format(score.mean()))
model_scores['LinearRegression'] = score.mean()
# Out:
# cross validation score : [0.87107967 0.86514799 0.86210195 0.89608763 0.86689218]
# scores mean : 0.8723

# %%
lr = LinearRegression()
lr = lr.fit(X_train, target)
pred_lr = np.expm1(lr.predict(X_test))

# %% [markdown]
# ## Lasso

# %%
lasso = Lasso(random_state=42)
score = cross_val_score(lasso, X_train, target, cv=5, scoring ='r2')
print('cross validation score : {}'.format(score))
print('scores mean : {:.4f}'.format(score.mean()))
model_scores['Lasso'] = score.mean()
# Out:
# cross validation score : [0.58634964 0.591572   0.594544   0.62963308 0.64299853]
# scores mean : 0.6090

# %%
lasso = Lasso(random_state=42)
lasso.fit(X_train, target)
pred_lasso = np.expm1(lasso.predict(X_test))

# %% [markdown]
# ## Ridge

# %%
ridge = Ridge(random_state=42)
score = cross_val_score(ridge, X_train, target, cv=5, scoring ='r2')
print('cross validation score : {}'.format(score))
print('scores mean : {:.4f}'.format(score.mean()))
model_scores['Ridge'] = score.mean()
# Out:
# cross validation score : [0.87125403 0.86489496 0.86173487 0.89575198 0.86699576]
# scores mean : 0.8721

# %%
ridge = Ridge(random_state=42)
ridge.fit(X_train, target)
pred_ridge = np.expm1(ridge.predict(X_test))

# %% [markdown]
# ## ElasticNet

# %%
elaNet = ElasticNet(random_state=42)
score = cross_val_score(elaNet, X_train, target, cv=5, scoring ='r2')
print('cross validation score : {}'.format(score))
print('scores mean : {:.4f}'.format(score.mean()))
model_scores['ElasticNet'] = score.mean()
# Out:
# cross validation score : [0.60261503 0.61365157 0.60313239 0.64363251 0.65605364]
# scores mean : 0.6238

# %%
elastic = ElasticNet(random_state=42)
elastic.fit(X_train, target)
pred_elastic = np.expm1(elastic.predict(X_test))

# %% [markdown]
# ## RandomForest

# %%
rf = RandomForestRegressor(random_state=42)
score = cross_val_score(rf, X_train, target, cv=5, scoring ='r2')
print('cross validation score : {}'.format(score))
print('scores mean : {:.4f}'.format(score.mean()))
model_scores['RandomForest'] = score.mean()
# Out:
# cross validation score : [0.86047907 0.84325039 0.84702761 0.88639258 0.87511182]
# scores mean : 0.8625

# %%
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, target)
pred_rf = np.expm1(rf.predict(X_test))

# %% [markdown]
# ## LightGBM

# %%
lgbm = LGBMRegressor(random_state=42)
score = cross_val_score(lgbm, X_train, target, cv=5, scoring ='r2')
print('cross validation score : {}'.format(score))
print('scores mean : {:.4f}'.format(score.mean()))
model_scores['LightGBM'] = score.mean()
# Out:
# cross validation score : [0.86721943 0.84518828 0.84253561 0.88801868 0.86673224]
# scores mean : 0.8619

# %%
lgbm = LGBMRegressor(random_state=42)
lgbm.fit(X_train, target)
pred_lgbm = np.expm1(lgbm.predict(X_test))

# %% [markdown]
# ## XGBoost

# %%
xgb = XGBRegressor(random_state=42)
score = cross_val_score(xgb, X_train, target, cv=5, scoring ='r2')
print('cross validation score : {}'.format(score))
print('scores mean : {:.4f}'.format(score.mean()))
model_scores['XGBoost'] = score.mean()
# Out:
# cross validation score : [0.85809451 0.83025985 0.84496754 0.86211946 0.86483139]
# scores mean : 0.8521

# %%
xgb = XGBRegressor(random_state=42)
xgb.fit(X_train, target)
pred_xgb = np.expm1(xgb.predict(X_test))

# %% [markdown]
# ## Model_scores

# %%
model_scores
# Out:
# {'LinearRegression': 0.8722618843455981,
#  'Lasso': 0.6090194502645424,
#  'Ridge': 0.8721263216471199,
#  'ElasticNet': 0.6238170282061839,
#  'RandomForest': 0.8624522916217042,
#  'LightGBM': 0.8619388452277542,
#  'XGBoost': 0.8520545474452209}

# %%
pd.DataFrame(model_scores.values(), index=model_scores.keys()).rename(columns={0:'R2'}).sort_values(by='R2', ascending=False)
# Out:
#                     R2
# LinearRegression  0.87
# Ridge             0.87
# RandomForest      0.86
# LightGBM          0.86
# XGBoost           0.85
# ElasticNet        0.62
# Lasso             0.61

# %% [markdown]
# ## Ensemble

# %%
pred_ensemble = pred_lr*0.2 + pred_ridge*0.2 + pred_lgbm*0.2 + pred_xgb*0.2 + pred_rf*0.2

# %%
# submission

submission_ensemble = pd.read_csv('./data/sample_submission.csv')

# %%
submission_ensemble['target'] = pred_ensemble

# %%
submission_ensemble.to_csv("./data/submission_ensemble.csv", index=False)
