# %% [markdown]
# # Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

from sklearn.ensemble import AdaBoostRegressor, AdaBoostClassifier
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingClassifier
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import KFold, RepeatedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler


pd.set_option('precision',2)

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
matplotlib.rc('figure', facecolor = 'w', edgecolor ='w')

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

# %%
print("train data's shape : {}".format(df_train.shape))
print("test data's shape : {}".format(df_test.shape))
# Out:
# train data's shape : (114, 11)
# test data's shape : (228, 10)

# %%
df_train.head()
# Out:
#    id                                    Species  Island Clutch Completion  \
# 0   0          Gentoo penguin (Pygoscelis papua)  Biscoe               Yes
# 1   1  Chinstrap penguin (Pygoscelis antarctica)   Dream                No
# 2   2          Gentoo penguin (Pygoscelis papua)  Biscoe               Yes
# 3   3          Gentoo penguin (Pygoscelis papua)  Biscoe               Yes
# 4   4          Gentoo penguin (Pygoscelis papua)  Biscoe                No
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)     Sex  \
# 0                50.0               15.3                  220    MALE
# 1                49.5               19.0                  200    MALE
# 2                45.1               14.4                  210  FEMALE
# 3                44.5               14.7                  214  FEMALE
# 4                49.6               16.0                  225    MALE
#
#    Delta 15 N (o/oo)  Delta 13 C (o/oo)  Body Mass (g)
# ...

# %%
df_test.head()
# Out:
#    id                                    Species  Island Clutch Completion  \
# 0   0  Chinstrap penguin (Pygoscelis antarctica)   Dream               Yes
# 1   1          Gentoo penguin (Pygoscelis papua)  Biscoe               Yes
# 2   2        Adelie Penguin (Pygoscelis adeliae)   Dream               Yes
# 3   3  Chinstrap penguin (Pygoscelis antarctica)   Dream               Yes
# 4   4        Adelie Penguin (Pygoscelis adeliae)  Biscoe                No
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)     Sex  \
# 0                52.0               20.7                210.0    MALE
# 1                55.9               17.0                228.0    MALE
# 2                38.9               18.8                190.0  FEMALE
# 3                45.2               16.6                191.0  FEMALE
# 4                37.9               18.6                172.0  FEMALE
#
#    Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0               9.43             -24.68
# ...

# %%
# id 제거
df_train.drop(['id'], axis=1, inplace=True)
df_test.drop(['id'], axis=1, inplace=True)

# %%
print('columns : {}'.format(len(df_train.columns)))
df_train.columns
# Out:
# columns : 10
# Index(['Species', 'Island', 'Clutch Completion', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Sex', 'Delta 15 N (o/oo)',
#        'Delta 13 C (o/oo)', 'Body Mass (g)'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Species              114 non-null    object
#  1   Island               114 non-null    object
#  2   Clutch Completion    114 non-null    object
#  3   Culmen Length (mm)   114 non-null    float64
#  4   Culmen Depth (mm)    114 non-null    float64
#  5   Flipper Length (mm)  114 non-null    int64
#  6   Sex                  111 non-null    object
#  7   Delta 15 N (o/oo)    111 non-null    float64
#  8   Delta 13 C (o/oo)    111 non-null    float64
#  9   Body Mass (g)        114 non-null    int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 9.0+ KB

# %%
df_train.describe()
# Out:
#        Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# count              114.00             114.00               114.00
# mean                44.61              17.01               203.05
# std                  5.32               1.94                14.65
# min                 33.50              13.20               174.00
# 25%                 40.33              15.22               190.00
# 50%                 45.20              17.25               199.00
# 75%                 49.08              18.60               216.00
# max                 55.10              21.10               231.00
#
#        Delta 15 N (o/oo)  Delta 13 C (o/oo)  Body Mass (g)
# count             111.00             111.00         114.00
# mean                8.74             -25.72        4327.85
# std                 0.57               0.86         781.77
# min                 7.63             -27.02        2700.00
# 25%                 8.27             -26.43        3675.00
# ...

# %% [markdown]
# ## null data

# %%
# train data
print('\nNull Data Count\n')
for i,cnt in enumerate(df_train.isnull().sum()):
    if cnt > 0:
        print("{} : {}".format(df_train.columns[i],cnt))
        
# test data
print('\nNull Data Count\n')
for i,cnt in enumerate(df_test.isnull().sum()):
    if cnt > 0:
        print("{} : {}".format(df_test.columns[i],cnt))
# Out:
# Null Data Count
#
# Sex : 3
# Delta 15 N (o/oo) : 3
# Delta 13 C (o/oo) : 3
#
# Null Data Count
#
# Sex : 6
# Delta 15 N (o/oo) : 9
# Delta 13 C (o/oo) : 8

# %%
# train data
print('Null Data Count\n')
for i,cnt in enumerate(df_train.isnull().sum()):
    if cnt > 0:
        print("{} : {}".format(df_train.columns[i],cnt))
        
print('\nNull Data Percent\n')
for i,per in enumerate(df_train.isnull().mean()):
    if per > 0:
        print("{} : {:.2f}%".format(df_train.columns[i],per*100))
# Out:
# Null Data Count
#
# Sex : 3
# Delta 15 N (o/oo) : 3
# Delta 13 C (o/oo) : 3
#
# Null Data Percent
#
# Sex : 2.63%
# Delta 15 N (o/oo) : 2.63%
# Delta 13 C (o/oo) : 2.63%

# %%
# test data
print('Null Data Count\n')
for i,cnt in enumerate(df_test.isnull().sum()):
    if cnt > 0:
        print("{} : {}".format(df_test.columns[i],cnt))
        
print('\nNull Data Percent\n')
for i,per in enumerate(df_test.isnull().mean()):
    if per > 0:
        print("{} : {:.2f}%".format(df_test.columns[i],per*100))
# Out:
# Null Data Count
#
# Sex : 6
# Delta 15 N (o/oo) : 9
# Delta 13 C (o/oo) : 8
#
# Null Data Percent
#
# Sex : 2.63%
# Delta 15 N (o/oo) : 3.95%
# Delta 13 C (o/oo) : 3.51%

# %%
msno.matrix(df=df_train.iloc[:,:], figsize=(8,8), color=(0.8, 0.5, 0.2))

# %%
msno.bar(df=df_train.iloc[:,:], figsize=(8,8), color=(0.8, 0.5, 0.2))

# %%
msno.bar(df=df_test.iloc[:,:], figsize=(8,8), color=(0.8, 0.5, 0.2))

# %% [markdown]
# ## Target
#
# > Body Mass (g)
# - 편향되어 보이지 않는다.

# %%
df_train['Body Mass (g)'].describe()
# Out:
# count     114.00
# mean     4327.85
# std       781.77
# min      2700.00
# 25%      3675.00
# 50%      4250.00
# 75%      4850.00
# max      6300.00
# Name: Body Mass (g), dtype: float64

# %%
plt.figure(figsize=(14,14))

plt.subplot(2,2,1)
plt.hist(df_train['Body Mass (g)'])
plt.title('Histogram - Body Mass (g)', fontdict={'fontsize':20})
plt.ylabel('Count')

plt.subplot(2,2,2)
plt.boxplot(df_train['Body Mass (g)'])
plt.title('Boxplot - Body Mass (g)', fontdict={'fontsize':20})

plt.subplot(2,2,3)
sns.kdeplot(df_train['Body Mass (g)'])
plt.title('KDE - Body Mass (g)', fontdict={'fontsize':20})

plt.subplot(2,2,4)
sns.distplot(df_train['Body Mass (g)'],
                   color='b',
                   label='Skewness : {:.2f}'.format(df_train['Body Mass (g)'].skew()))
plt.legend(loc='best')
plt.title('Distplot - Body Mass (g)', fontdict={'fontsize':20})

plt.show()

# %% [markdown]
# # EDA

# %%
df_train.columns
# Out:
# Index(['Species', 'Island', 'Clutch Completion', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Sex', 'Delta 15 N (o/oo)',
#        'Delta 13 C (o/oo)', 'Body Mass (g)'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Species              114 non-null    object
#  1   Island               114 non-null    object
#  2   Clutch Completion    114 non-null    object
#  3   Culmen Length (mm)   114 non-null    float64
#  4   Culmen Depth (mm)    114 non-null    float64
#  5   Flipper Length (mm)  114 non-null    int64
#  6   Sex                  111 non-null    object
#  7   Delta 15 N (o/oo)    111 non-null    float64
#  8   Delta 13 C (o/oo)    111 non-null    float64
#  9   Body Mass (g)        114 non-null    int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 9.0+ KB

# %%
numerical_feature =  df_train.columns[df_train.dtypes!=object][:-1] # Body Mass 제외
categorical_feature = df_train.columns[df_train.dtypes==object]

print('수치형 데이터 : {}'.format(list(numerical_feature)))
print('카테고리형 데이터 : {}'.format(list(categorical_feature)))
# Out:
# 수치형 데이터 : ['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']
# 카테고리형 데이터 : ['Species', 'Island', 'Clutch Completion', 'Sex']

# %% [markdown]
# ## Numerical Feature

# %%
numerical_feature
# Out:
# Index(['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'],
#       dtype='object')

# %% [markdown]
# ### Culmen Length (mm)
#
# > 펭귄 옆모습 기준 부리의 가로 길이
# - 편향되어있지 않음

# %%
df_train['Culmen Length (mm)'].describe()
# Out:
# count    114.00
# mean      44.61
# std        5.32
# min       33.50
# 25%       40.33
# 50%       45.20
# 75%       49.08
# max       55.10
# Name: Culmen Length (mm), dtype: float64

# %%
fig,ax = plt.subplots(1,1,figsize=(7,7))
fig = sns.distplot(df_train['Culmen Length (mm)'],
                   color='b',
                   label='Skewness : {:.2f}'.format(df_train['Culmen Length (mm)'].skew()),
                   ax=ax)
fig = fig.legend(loc='best')

# %% [markdown]
# ### Culmen Depth (mm)
#
# > 펭귄 옆모습 기준 부리의 세로 길이
# - 편향되어있지 않음

# %%
df_train['Culmen Depth (mm)'].describe()
# Out:
# count    114.00
# mean      17.01
# std        1.94
# min       13.20
# 25%       15.22
# 50%       17.25
# 75%       18.60
# max       21.10
# Name: Culmen Depth (mm), dtype: float64

# %%
fig,ax = plt.subplots(1,1,figsize=(7,7))
fig = sns.distplot(df_train['Culmen Depth (mm)'],
                   color='b',
                   label='Skewness : {:.2f}'.format(df_train['Culmen Depth (mm)'].skew()),
                   ax=ax)
fig = fig.legend(loc='best')

# %% [markdown]
# ### Flipper Length (mm)
#
# > 펭귄의 팔(날개) 길이
# - 편향되어있지 않음

# %%
df_train['Flipper Length (mm)'].describe()
# Out:
# count    114.00
# mean     203.05
# std       14.65
# min      174.00
# 25%      190.00
# 50%      199.00
# 75%      216.00
# max      231.00
# Name: Flipper Length (mm), dtype: float64

# %%
fig,ax = plt.subplots(1,1,figsize=(7,7))
fig = sns.distplot(df_train['Flipper Length (mm)'],
                   color='b',
                   label='Skewness : {:.2f}'.format(df_train['Flipper Length (mm)'].skew()),
                   ax=ax)
fig = fig.legend(loc='best')

# %% [markdown]
# ### Delta 15 N (o/oo)
#
# > 토양에 따라 변화하는 안정 동위원소 15N:14N의 비율
# - 편향되어있지 않음

# %%
df_train['Delta 15 N (o/oo)'].describe()
# Out:
# count    111.00
# mean       8.74
# std        0.57
# min        7.63
# 25%        8.27
# 50%        8.63
# 75%        9.26
# max       10.03
# Name: Delta 15 N (o/oo), dtype: float64

# %%
fig,ax = plt.subplots(1,1,figsize=(7,7))
fig = sns.distplot(df_train['Delta 15 N (o/oo)'],
                   color='b',
                   label='Skewness : {:.2f}'.format(df_train['Delta 15 N (o/oo)'].skew()),
                   ax=ax)
fig = fig.legend(loc='best')

# %% [markdown]
# ### Delta 13 C (o/oo)
#
# > 먹이에 따라 변화하는 안정 동위원소 13C:12C의 비율
# - 편향되어있지 않음

# %%
df_train['Delta 13 C (o/oo)'].describe()
# Out:
# count    111.00
# mean     -25.72
# std        0.86
# min      -27.02
# 25%      -26.43
# 50%      -25.96
# 75%      -25.01
# max      -24.10
# Name: Delta 13 C (o/oo), dtype: float64

# %%
fig,ax = plt.subplots(1,1,figsize=(7,7))
fig = sns.distplot(df_train['Delta 13 C (o/oo)'],
                   color='b',
                   label='Skewness : {:.2f}'.format(df_train['Delta 13 C (o/oo)'].skew()),
                   ax=ax)
fig = fig.legend(loc='best')

# %% [markdown]
# ### Delta with Species and Island

# %% [markdown]
# #### Delta 15 N

# %%
plt.figure(figsize=(14,7))
sns.boxplot(x='Island', y='Delta 15 N (o/oo)', hue='Species',
           data=df_train[['Island', 'Species','Delta 15 N (o/oo)']])
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.boxplot(x='Species', y='Delta 15 N (o/oo)', hue='Island',
           data=df_train[['Island', 'Species','Delta 15 N (o/oo)']])
plt.show()

# %% [markdown]
# #### Delta 13 C

# %%
plt.figure(figsize=(14,7))
sns.boxplot(x='Island', y='Delta 13 C (o/oo)', hue='Species',
           data=df_train[['Island', 'Species','Delta 13 C (o/oo)']])
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.boxplot(x='Species', y='Delta 13 C (o/oo)', hue='Island',
           data=df_train[['Island', 'Species','Delta 13 C (o/oo)']])
plt.show()

# %% [markdown]
# ### With target
#
# > 정보
# - 두 무리로 나뉘는 Feature들이 있는 거 같기도 하다

# %%
numerical_feature
# Out:
# Index(['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'],
#       dtype='object')

# %%
feature = numerical_feature
target = 'Body Mass (g)'

plt.figure(figsize=(21,14))
plt.suptitle("Scatter Plot", fontsize=40)

for i in range(len(feature)):
    plt.subplot(2,3,i+1)
    plt.xlabel(feature[i], fontsize=15)
    plt.ylabel(target)
    corr_score = df_train[[feature[i],target]].corr().iloc[0,1].round(2)
    c = 'red' if corr_score>0 else 'blue'
    plt.scatter(df_train[feature[i]], df_train[target], color=c, label='corr={}'.format(corr_score))
    plt.legend(fontsize=15)
    
plt.tight_layout(rect=[0,0.03,1,0.95])
plt.show()

# %% [markdown]
# ## Categorical Feature

# %%
categorical_feature
# Out:
# Index(['Species', 'Island', 'Clutch Completion', 'Sex'], dtype='object')

# %% [markdown]
# ### Species
#
# > 펭귄의 종

# %%
df_train['Species'].unique()
# Out:
# array(['Gentoo penguin (Pygoscelis papua)',
#        'Chinstrap penguin (Pygoscelis antarctica)',
#        'Adelie Penguin (Pygoscelis adeliae)'], dtype=object)

# %%
df_train['Species'].value_counts()
# Out:
# Gentoo penguin (Pygoscelis papua)            48
# Adelie Penguin (Pygoscelis adeliae)          41
# Chinstrap penguin (Pygoscelis antarctica)    25
# Name: Species, dtype: int64

# %%
plt.figure(figsize=(7,7))
sns.countplot(df_train['Species'])
plt.title("Countplot - Species", fontsize=20)
plt.show()

# %%
df_train[['Species', 'Body Mass (g)']].groupby(['Species'], as_index=True).describe()
# Out:
#                                           Body Mass (g)                   \
#                                                   count     mean     std
# Species
# Adelie Penguin (Pygoscelis adeliae)                41.0  3801.22  435.60
# Chinstrap penguin (Pygoscelis antarctica)          25.0  3756.00  419.16
# Gentoo penguin (Pygoscelis papua)                  48.0  5075.52  481.04
#
#                                                                            \
#                                               min     25%     50%     75%
# Species
# Adelie Penguin (Pygoscelis adeliae)        3000.0  3475.0  3750.0  4100.0
# Chinstrap penguin (Pygoscelis antarctica)  2700.0  3500.0  3675.0  3950.0
# Gentoo penguin (Pygoscelis papua)          4150.0  4700.0  5000.0  5500.0
#
#
#                                               max
# Species
# Adelie Penguin (Pygoscelis adeliae)        4725.0
# Chinstrap penguin (Pygoscelis antarctica)  4550.0
# ...

# %%
species = df_train['Species'].unique()

plt.figure(figsize=(7,7))
df_train['Body Mass (g)'][df_train["Species"] == species[0]].plot(kind='kde')
df_train['Body Mass (g)'][df_train["Species"] == species[1]].plot(kind='kde')
df_train['Body Mass (g)'][df_train["Species"] == species[2]].plot(kind='kde')

plt.xlabel("Body Mass (g)")
plt.title('Body Mass Distribution within Species')
plt.legend(species)

plt.show()

# %% [markdown]
# ### Island
#
# > 샘플들이 수집된 Palmer Station 근처 섬 이름

# %%
df_train['Island'].unique()
# Out:
# array(['Biscoe', 'Dream', 'Torgersen'], dtype=object)

# %%
df_train['Island'].value_counts()
# Out:
# Biscoe       57
# Dream        44
# Torgersen    13
# Name: Island, dtype: int64

# %%
plt.figure(figsize=(7,7))
sns.countplot(df_train['Island'])
plt.title("Countplot - Island", fontsize=20)
plt.show()

# %%
df_train[['Island', 'Body Mass (g)']].groupby(['Island'], as_index=True).describe()
# Out:
#           Body Mass (g)                                                   \
#                   count     mean     std     min     25%     50%     75%
# Island
# Biscoe             57.0  4878.95  664.15  3075.0  4575.0  4850.0  5350.0
# Dream              44.0  3764.77  432.18  2700.0  3450.0  3700.0  3987.5
# Torgersen          13.0  3817.31  373.94  3275.0  3600.0  3700.0  3900.0
#
#
#               max
# Island
# Biscoe     6300.0
# Dream      4650.0
# Torgersen  4700.0

# %%
island = df_train['Island'].unique()

plt.figure(figsize=(7,7))
df_train['Body Mass (g)'][df_train["Island"] == island[0]].plot(kind='kde')
df_train['Body Mass (g)'][df_train["Island"] == island[1]].plot(kind='kde')
df_train['Body Mass (g)'][df_train["Island"] == island[2]].plot(kind='kde')

plt.xlabel("Body Mass (g)")
plt.title('Body Mass Distribution within Island')
plt.legend(island)

plt.show()

# %% [markdown]
# ### Species and Island
#
# > 정보
# - Biscoe 섬의 Gentoo penguin (Pygoscelis papua)종이 혼자 평균이 다름

# %%
df_train[['Species','Island', 'Body Mass (g)']].groupby(['Island', 'Species'], as_index=True).describe()
# Out:
#                                                     Body Mass (g)           \
#                                                             count     mean
# Island    Species
# Biscoe    Adelie Penguin (Pygoscelis adeliae)                 9.0  3830.56
#           Gentoo penguin (Pygoscelis papua)                  48.0  5075.52
# Dream     Adelie Penguin (Pygoscelis adeliae)                19.0  3776.32
#           Chinstrap penguin (Pygoscelis antarctica)          25.0  3756.00
# Torgersen Adelie Penguin (Pygoscelis adeliae)                13.0  3817.31
#
#                                                                              \
#                                                         std     min     25%
# Island    Species
# Biscoe    Adelie Penguin (Pygoscelis adeliae)        509.71  3075.0  3400.0
#           Gentoo penguin (Pygoscelis papua)          481.04  4150.0  4700.0
# Dream     Adelie Penguin (Pygoscelis adeliae)        460.11  3000.0  3412.5
# ...

# %%
for i in range(3):
    print(species[i])
# Out:
# Gentoo penguin (Pygoscelis papua)
# Chinstrap penguin (Pygoscelis antarctica)
# Adelie Penguin (Pygoscelis adeliae)

# %%
species = df_train['Species'].unique()
island = df_train['Island'].unique()

plt.figure(figsize=(7,7))
df_train['Body Mass (g)'][(df_train["Island"] == "Biscoe") & (df_train['Species'] == species[0])].plot(kind='kde')
df_train['Body Mass (g)'][(df_train["Island"] == "Biscoe") & (df_train['Species'] == species[2])].plot(kind='kde')
df_train['Body Mass (g)'][(df_train["Island"] == "Dream") & (df_train['Species'] == species[1])] .plot(kind='kde')
df_train['Body Mass (g)'][(df_train["Island"] == "Dream") & (df_train['Species'] == species[2])] .plot(kind='kde')
df_train['Body Mass (g)'][(df_train["Island"] == "Torgersen") & (df_train['Species'] == species[2])].plot(kind='kde')

plt.xlabel("Body Mass (g)")
plt.title('Body Mass Distribution within Island & Species')
plt.legend(range(5))

plt.show()

# %% [markdown]
# ### Clutch Completion
#
# > 관찰된 펭귄 둥지의 알이 2개인 경우 Full Clutch이며 Yes로 표기
# - 90%가 Yes
# - 삭제해도 될 듯?? -> 다른 Feature들이랑 관계보고 결정하자

# %%
df_train['Clutch Completion'].value_counts()
# Out:
# Yes    102
# No      12
# Name: Clutch Completion, dtype: int64

# %%
print("Yes의 비율 : {:.2f}".format(df_train['Clutch Completion'].map({'Yes':1, 'No':0}).mean()*100))
# Out:
# Yes의 비율 : 89.47

# %%
plt.figure(figsize=(7,7))
sns.countplot(df_train['Clutch Completion'])
plt.title("Countplot - Clutch Completion", fontsize=20)
plt.show()

# %% [markdown]
# ### Sex
#
# > 펭귄의 성별
# - Male의 평균이 좀 더 크다

# %%
df_train['Sex'].value_counts()
# Out:
# MALE      56
# FEMALE    55
# Name: Sex, dtype: int64

# %%
df_train[['Sex', 'Body Mass (g)']].groupby(['Sex'], as_index=True).describe()
# Out:
#        Body Mass (g)
#                count     mean     std     min     25%     50%     75%     max
# Sex
# FEMALE          55.0  4000.91  654.88  2700.0  3475.0  3750.0  4700.0  5200.0
# MALE            56.0  4659.82  774.77  3250.0  3950.0  4575.0  5362.5  6300.0

# %%
sex = df_train['Sex'].unique()

plt.figure(figsize=(7,7))
df_train['Body Mass (g)'][df_train["Sex"] == sex[0]].plot(kind='kde')
df_train['Body Mass (g)'][df_train["Sex"] == sex[1]].plot(kind='kde')

plt.xlabel("Body Mass (g)")
plt.title('Body Mass Distribution within Sex')
plt.legend(sex)

plt.show()

# %% [markdown]
# ### With target

# %%
# violin plot
feature = categorical_feature
target = 'Body Mass (g)'

plt.figure(figsize=(14,14))
plt.suptitle("Violin Plot", fontsize=40)

for i in range(len(feature)):
    plt.subplot(2,2,i+1)
    plt.xlabel(feature[i], fontsize=15)
    plt.ylabel(target, fontsize=15)
    sns.violinplot(x=df_train[feature[i]], y=df_train[target])
    
plt.tight_layout(rect=[0,0.03,1,0.95])
plt.show()

# %% [markdown]
# ## Correlation

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# 상관계수 계산을 위해 텍스트 형식의 데이터를 숫자로 변환

corr_df = df_train.copy()
corr_df[categorical_feature] = corr_df[categorical_feature].astype(str).apply(LabelEncoder().fit_transform)

# %%
# 상관관계 분석도
plt.figure(figsize=(14,7))

heat_table = corr_df.corr()
mask = np.zeros_like(heat_table)
mask[np.triu_indices_from(mask)] = True

heatmap_ax = sns.heatmap(heat_table, annot=True, mask=mask, cmap='coolwarm')
heatmap_ax.set_xticklabels(heatmap_ax.get_xticklabels(), fontsize=15, rotation=45)
heatmap_ax.set_yticklabels(heatmap_ax.get_yticklabels(), fontsize=15)
plt.title("correlation between features", fontsize=40)

plt.show()

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Fill Null
#
# > 방법
# - 다른 Feature 사용해서 modeling - prediction해서 Fill Null

# %%
# train data
print('Null Data Count\n')
for i,cnt in enumerate(df_train.isnull().sum()):
    if cnt > 0:
        print("{} : {}".format(df_train.columns[i],cnt))
else:
    print("\tIt doesn't have Null data")
        
# test data
print('\nNull Data Count\n')
for i,cnt in enumerate(df_test.isnull().sum()):
    if cnt > 0:
        print("{} : {}".format(df_test.columns[i],cnt))
else:
    print("\tIt doesn't have Null data")
# Out:
# Null Data Count
#
# Sex : 3
# Delta 15 N (o/oo) : 3
# Delta 13 C (o/oo) : 3
# 	It doesn't have Null data
#
# Null Data Count
#
# Sex : 6
# Delta 15 N (o/oo) : 9
# Delta 13 C (o/oo) : 8
# 	It doesn't have Null data

# %% [markdown]
# ### Sex

# %%
# 결측치를 채우기 전에 일단 범주형 데이터를 숫자형 데이터로 처리

# Sex
df_train['Sex'] = df_train['Sex'].map({'MALE':1,
                                      'FEMALE':2})
df_test['Sex'] = df_test['Sex'].map({'MALE':1,
                                      'FEMALE':2})

# %%
df_train = pd.get_dummies(df_train, columns=['Species','Island'], prefix=['Species','Island'])
df_test = pd.get_dummies(df_test, columns=['Species','Island'], prefix=['Species','Island'])

# %%
df_train.columns
# Out:
# Index(['Clutch Completion', 'Culmen Length (mm)', 'Culmen Depth (mm)',
#        'Flipper Length (mm)', 'Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)',
#        'Body Mass (g)', 'Species_Adelie Penguin (Pygoscelis adeliae)',
#        'Species_Chinstrap penguin (Pygoscelis antarctica)',
#        'Species_Gentoo penguin (Pygoscelis papua)', 'Island_Biscoe',
#        'Island_Dream', 'Island_Torgersen'],
#       dtype='object')

# %%
# Clutch Completion 포함 X
sex_feature = ['Culmen Length (mm)', 'Culmen Depth (mm)','Flipper Length (mm)',
               'Species_Adelie Penguin (Pygoscelis adeliae)','Species_Chinstrap penguin (Pygoscelis antarctica)',
               'Species_Gentoo penguin (Pygoscelis papua)', 'Island_Biscoe','Island_Dream', 'Island_Torgersen']

sex_model = AdaBoostClassifier()
sex_model.fit(df_train[sex_feature].iloc[df_train['Sex'].dropna().index], df_train['Sex'].iloc[df_train['Sex'].dropna().index])
df_train['Sex'].iloc[np.where(df_train['Sex'].isnull()==True)] = sex_model.predict(df_train[df_train['Sex'].isnull()][sex_feature])
df_test['Sex'].iloc[np.where(df_test['Sex'].isnull()==True)] = sex_model.predict(df_test[df_test['Sex'].isnull()][sex_feature])

# %% [markdown]
# ### Delta 15 N

# %%
# Sex도 포함
Delta_feature = ['Culmen Length (mm)', 'Culmen Depth (mm)','Flipper Length (mm)',
               'Species_Adelie Penguin (Pygoscelis adeliae)','Species_Chinstrap penguin (Pygoscelis antarctica)',
               'Species_Gentoo penguin (Pygoscelis papua)', 'Island_Biscoe','Island_Dream', 'Island_Torgersen', 'Sex']

d15_model = AdaBoostRegressor()
d15_model.fit(df_train[Delta_feature].iloc[df_train['Delta 15 N (o/oo)'].dropna().index],
             df_train['Delta 15 N (o/oo)'].iloc[df_train['Delta 15 N (o/oo)'].dropna().index])
df_train['Delta 15 N (o/oo)'].iloc[np.where(df_train['Delta 15 N (o/oo)'].isnull()==True)] = d15_model.predict(df_train[df_train['Delta 15 N (o/oo)'].isnull()][Delta_feature])
df_test['Delta 15 N (o/oo)'].iloc[np.where(df_test['Delta 15 N (o/oo)'].isnull()==True)] = d15_model.predict(df_test[df_test['Delta 15 N (o/oo)'].isnull()][Delta_feature])

# %% [markdown]
# ### Delta 13 C

# %%
d13_model = LinearRegression()

d13_model.fit(df_train[Delta_feature].iloc[df_train['Delta 13 C (o/oo)'].dropna().index],
             df_train['Delta 13 C (o/oo)'].iloc[df_train['Delta 13 C (o/oo)'].dropna().index])
df_train['Delta 13 C (o/oo)'].iloc[np.where(df_train['Delta 13 C (o/oo)'].isnull()==True)] = d13_model.predict(df_train[df_train['Delta 13 C (o/oo)'].isnull()][Delta_feature])
df_test['Delta 13 C (o/oo)'].iloc[np.where(df_test['Delta 13 C (o/oo)'].isnull()==True)] = d13_model.predict(df_test[df_test['Delta 13 C (o/oo)'].isnull()][Delta_feature])

# %%
# train data
print('Null Data Count\n')
for i,cnt in enumerate(df_train.isnull().sum()):
    if cnt > 0:
        print("{} : {}".format(df_train.columns[i],cnt))
else:
    print("\tIt doesn't have Null data")
        
# test data
print('\nNull Data Count\n')
for i,cnt in enumerate(df_test.isnull().sum()):
    if cnt > 0:
        print("{} : {}".format(df_test.columns[i],cnt))
else:
    print("\tIt doesn't have Null data")
# Out:
# Null Data Count
#
# 	It doesn't have Null data
#
# Null Data Count
#
# 	It doesn't have Null data

# %% [markdown]
# ## Change numerical to categorical
# - 결측값 처리 부분에서 'Sex'를 수치형으로 바꿈

# %%
# Sex
df_train['Sex'] = df_train['Sex'].map({1:'MALE', 2:'FEMALE'})
df_test['Sex'] = df_test['Sex'].map({1:'MALE', 2:'FEMALE'})

# %%
df_train.head()
# Out:
#   Clutch Completion  Culmen Length (mm)  Culmen Depth (mm)  \
# 0               Yes                50.0               15.3
# 1                No                49.5               19.0
# 2               Yes                45.1               14.4
# 3               Yes                44.5               14.7
# 4                No                49.6               16.0
#
#    Flipper Length (mm)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0                  220    MALE               8.31             -25.19
# 1                  200    MALE               9.63             -24.35
# 2                  210  FEMALE               8.52             -27.02
# 3                  214  FEMALE               8.20             -26.17
# 4                  225    MALE               8.38             -26.84
#
#    Body Mass (g)  Species_Adelie Penguin (Pygoscelis adeliae)  \
# 0           5550                                            0
# 1           3800                                            0
# ...

# %% [markdown]
# ## One-hot encoding

# %%
df_train = pd.get_dummies(df_train, columns=['Sex'], prefix=['Sex'])
df_test = pd.get_dummies(df_test, columns=['Sex'], prefix=['Sex'])

# %%
df_train.head()
# Out:
#   Clutch Completion  Culmen Length (mm)  Culmen Depth (mm)  \
# 0               Yes                50.0               15.3
# 1                No                49.5               19.0
# 2               Yes                45.1               14.4
# 3               Yes                44.5               14.7
# 4                No                49.6               16.0
#
#    Flipper Length (mm)  Delta 15 N (o/oo)  Delta 13 C (o/oo)  Body Mass (g)  \
# 0                  220               8.31             -25.19           5550
# 1                  200               9.63             -24.35           3800
# 2                  210               8.52             -27.02           4400
# 3                  214               8.20             -26.17           4850
# 4                  225               8.38             -26.84           5700
#
#    Species_Adelie Penguin (Pygoscelis adeliae)  \
# 0                                            0
# 1                                            0
# ...

# %% [markdown]
# ## Drop columns

# %%
def del_columns(df):
    cols = ['Id', 'Clutch Completion']
    for col in cols:
        if col in df.columns:
            df.drop([col], axis=1, inplace=True)
    
    return df

# %%
df_train = del_columns(df_train)
df_test = del_columns(df_test)

# %%
df_train.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0                50.0               15.3                  220
# 1                49.5               19.0                  200
# 2                45.1               14.4                  210
# 3                44.5               14.7                  214
# 4                49.6               16.0                  225
#
#    Delta 15 N (o/oo)  Delta 13 C (o/oo)  Body Mass (g)  \
# 0               8.31             -25.19           5550
# 1               9.63             -24.35           3800
# 2               8.52             -27.02           4400
# 3               8.20             -26.17           4850
# 4               8.38             -26.84           5700
#
#    Species_Adelie Penguin (Pygoscelis adeliae)  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# ...

# %% [markdown]
# # Modeling
#
# > Model
# - LinearRegression
# - Lasso
# - Ridge
# - ElasticNet
# - RandomForest
# - LightGBM
# - XGBoost
#
# > Validation
# - K-Fold

# %%
def RMSE(true, pred):
    score = np.sqrt(np.mean(np.square(true-pred)))
    return score

# %%
X_train = df_train.drop('Body Mass (g)', axis=1).values
target = df_train['Body Mass (g)'].values

X_test = df_test.values

# %%
print(target.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (114,)
# (114, 13)
# (228, 13)

# %%
model_rmse = dict()

# %% [markdown]
# ## LinearRegression

# %%
feature = X_train

lr = LinearRegression()

kfold = KFold(n_splits=5)

cv_rmse = [] # 각 cv회차의 rmse 점수를 계산하여 넣어줄 리스트를 생성. 이후 RMSE값의 평균을 구하기 위해 사용.
n_iter =0 # 반복 횟수 값을 초기 설정.

for train_idx, test_idx in kfold.split(feature):
    x_train, x_test = feature[train_idx], feature[test_idx]
    y_train, y_test = target[train_idx], target[test_idx]
    
    lr = lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    n_iter += 1
    
    error = RMSE(y_test, pred)
    train_size = x_train.shape[0]
    test_size = x_test.shape[0]
    
    print('\n{0}번째 교차 검증 RMSE : {1}, 학습 데이터 크기 : {2}, 검증 데이터 크기 : {3}'.format(n_iter, error, train_size, test_size))
    
    cv_rmse.append(error)
    
print('\n ==> 이 방정식의 평균 에러(RMSE)는 {} 입니다.'.format(np.mean(cv_rmse)))
model_rmse['LinearRegression'] = np.mean(cv_rmse)
# Out:
# 1번째 교차 검증 RMSE : 278.8385254452833, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 2번째 교차 검증 RMSE : 419.7317775791514, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 3번째 교차 검증 RMSE : 349.3815621785865, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 4번째 교차 검증 RMSE : 243.369674455569, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 5번째 교차 검증 RMSE : 336.64593501012337, 학습 데이터 크기 : 92, 검증 데이터 크기 : 22
#
#  ==> 이 방정식의 평균 에러(RMSE)는 325.5934949337427 입니다.

# %%
lr = LinearRegression()
lr = lr.fit(X_train, target)
y_pred_lr = lr.predict(X_test)

# %%
# submission

submission_lr = pd.read_csv('./data/sample_submission.csv')
submission_lr['Body Mass (g)'] = y_pred_lr

# %%
# submission_lr.to_csv("./data/submission_lr.csv", index=False)

# %% [markdown]
# ## Lasso

# %%
feature = X_train

lasso = Lasso()

kfold = KFold(n_splits=5)

cv_rmse = [] # 각 cv회차의 rmse 점수를 계산하여 넣어줄 리스트를 생성. 이후 RMSE값의 평균을 구하기 위해 사용.
n_iter =0 # 반복 횟수 값을 초기 설정.

for train_idx, test_idx in kfold.split(feature):
    x_train, x_test = feature[train_idx], feature[test_idx]
    y_train, y_test = target[train_idx], target[test_idx]
    
    lasso.fit(x_train, y_train)
    pred = lasso.predict(x_test)
    n_iter += 1
    
    error = RMSE(y_test, pred)
    train_size = x_train.shape[0]
    test_size = x_test.shape[0]
    
    print('\n{0}번째 교차 검증 RMSE : {1}, 학습 데이터 크기 : {2}, 검증 데이터 크기 : {3}'.format(n_iter, error, train_size, test_size))
    
    cv_rmse.append(error)
    
print('\n ==> 이 방정식의 평균 에러(RMSE)는 {} 입니다.'.format(np.mean(cv_rmse)))
model_rmse['Lasso'] = np.mean(cv_rmse)
# Out:
# 1번째 교차 검증 RMSE : 280.6656886349677, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 2번째 교차 검증 RMSE : 413.46629792452694, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 3번째 교차 검증 RMSE : 351.74406592876846, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 4번째 교차 검증 RMSE : 237.3103042988215, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 5번째 교차 검증 RMSE : 336.5795336292613, 학습 데이터 크기 : 92, 검증 데이터 크기 : 22
#
#  ==> 이 방정식의 평균 에러(RMSE)는 323.95317808326917 입니다.

# %%
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

lasso_alphas = np.linspace(0, 0.2, 21)
lasso = Lasso()

grid = dict()
grid['alpha'] = lasso_alphas

gscv = GridSearchCV(lasso, grid, scoring='neg_mean_absolute_error',
                    cv=cv, n_jobs=-1)
results = gscv.fit(X_train, target)

print('MAE: %.5f' % results.best_score_)
print('Config: %s' % results.best_params_)
# Out:
# MAE: -241.20388
# Config: {'alpha': 0.2}

# %%
lasso = Lasso()
lasso.fit(X_train, target)
y_pred_lasso = lasso.predict(X_test)

# %%
# submission

submission_lasso = pd.read_csv('./data/sample_submission.csv')
submission_lasso['Body Mass (g)'] = y_pred_lasso

# %%
# submission_lasso.to_csv("./data/submission_lasso.csv", index=False)

# %% [markdown]
# ## Ridge

# %%
feature = X_train

ridge = Ridge()

kfold = KFold(n_splits=5)

cv_rmse = [] # 각 cv회차의 rmse 점수를 계산하여 넣어줄 리스트를 생성. 이후 RMSE값의 평균을 구하기 위해 사용.
n_iter =0 # 반복 횟수 값을 초기 설정.

for train_idx, test_idx in kfold.split(feature):
    x_train, x_test = feature[train_idx], feature[test_idx]
    y_train, y_test = target[train_idx], target[test_idx]
    
    ridge.fit(x_train, y_train)
    pred = ridge.predict(x_test)
    n_iter += 1
    
    error = RMSE(y_test, pred)
    train_size = x_train.shape[0]
    test_size = x_test.shape[0]
    
    print('\n{0}번째 교차 검증 RMSE : {1}, 학습 데이터 크기 : {2}, 검증 데이터 크기 : {3}'.format(n_iter, error, train_size, test_size))
    
    cv_rmse.append(error)
    
print('\n ==> 이 방정식의 평균 에러(RMSE)는 {} 입니다.'.format(np.mean(cv_rmse)))
model_rmse['Ridge'] = np.mean(cv_rmse)
# Out:
# 1번째 교차 검증 RMSE : 288.5329593485321, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 2번째 교차 검증 RMSE : 392.6506959916596, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 3번째 교차 검증 RMSE : 358.4745587468555, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 4번째 교차 검증 RMSE : 232.80647484736105, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 5번째 교차 검증 RMSE : 340.1526530784938, 학습 데이터 크기 : 92, 검증 데이터 크기 : 22
#
#  ==> 이 방정식의 평균 에러(RMSE)는 322.52346840258036 입니다.

# %%
ridge = Ridge()
ridge.fit(X_train, target)
y_pred_ridge = ridge.predict(X_test)

# %%
# submission

submission_ridge = pd.read_csv('./data/sample_submission.csv')
submission_ridge['Body Mass (g)'] = y_pred_ridge

# %%
# submission_ridge.to_csv("./data/submission_ridge.csv", index=False)

# %% [markdown]
# ## ElasticNet

# %%
feature = X_train

elaNet = ElasticNet()

kfold = KFold(n_splits=5)

cv_rmse = [] # 각 cv회차의 rmse 점수를 계산하여 넣어줄 리스트를 생성. 이후 RMSE값의 평균을 구하기 위해 사용.
n_iter =0 # 반복 횟수 값을 초기 설정.

for train_idx, test_idx in kfold.split(feature):
    x_train, x_test = feature[train_idx], feature[test_idx]
    y_train, y_test = target[train_idx], target[test_idx]
    
    elaNet.fit(x_train, y_train)
    pred = elaNet.predict(x_test)
    n_iter += 1
    
    error = RMSE(y_test, pred)
    train_size = x_train.shape[0]
    test_size = x_test.shape[0]
    
    print('\n{0}번째 교차 검증 RMSE : {1}, 학습 데이터 크기 : {2}, 검증 데이터 크기 : {3}'.format(n_iter, error, train_size, test_size))
    
    cv_rmse.append(error)
    
print('\n ==> 이 방정식의 평균 에러(RMSE)는 {} 입니다.'.format(np.mean(cv_rmse)))
model_rmse['ElasticNet'] = np.mean(cv_rmse)
# Out:
# 1번째 교차 검증 RMSE : 359.9825953677936, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 2번째 교차 검증 RMSE : 351.59735870822095, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 3번째 교차 검증 RMSE : 452.1806111208906, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 4번째 교차 검증 RMSE : 223.18683322900802, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 5번째 교차 검증 RMSE : 369.8112523624764, 학습 데이터 크기 : 92, 검증 데이터 크기 : 22
#
#  ==> 이 방정식의 평균 에러(RMSE)는 351.35173015767793 입니다.

# %%
elastic = ElasticNet()
elastic.fit(X_train, target)
y_pred_elastic = elastic.predict(X_test)

# %%
# submission

submission_elastic = pd.read_csv('./data/sample_submission.csv')
submission_elastic['Body Mass (g)'] = y_pred_elastic

# %%
# submission_elastic.to_csv("./data/submission_elasticNet.csv", index=False)

# %% [markdown]
# ## RandomForest

# %%
feature = X_train

rf = RandomForestRegressor()

kfold = KFold(n_splits=5)

cv_rmse = [] # 각 cv회차의 rmse 점수를 계산하여 넣어줄 리스트를 생성. 이후 RMSE값의 평균을 구하기 위해 사용.
n_iter =0 # 반복 횟수 값을 초기 설정.

for train_idx, test_idx in kfold.split(feature):
    x_train, x_test = feature[train_idx], feature[test_idx]
    y_train, y_test = target[train_idx], target[test_idx]
    
    rf.fit(x_train, y_train)
    pred = rf.predict(x_test)
    n_iter += 1
    
    error = RMSE(y_test, pred)
    train_size = x_train.shape[0]
    test_size = x_test.shape[0]
    
    print('\n{0}번째 교차 검증 RMSE : {1}, 학습 데이터 크기 : {2}, 검증 데이터 크기 : {3}'.format(n_iter, error, train_size, test_size))
    
    cv_rmse.append(error)
    
print('\n ==> 이 방정식의 평균 에러(RMSE)는 {} 입니다.'.format(np.mean(cv_rmse)))
model_rmse['RandomForest'] = np.mean(cv_rmse)
# Out:
# 1번째 교차 검증 RMSE : 290.45357613791634, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 2번째 교차 검증 RMSE : 420.38695295809464, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 3번째 교차 검증 RMSE : 372.7903449720068, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 4번째 교차 검증 RMSE : 260.8185745002603, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 5번째 교차 검증 RMSE : 362.5181421792445, 학습 데이터 크기 : 92, 검증 데이터 크기 : 22
#
#  ==> 이 방정식의 평균 에러(RMSE)는 341.39351814950453 입니다.

# %%
rf = RandomForestRegressor()
rf.fit(X_train, target)
y_pred_rf = rf.predict(X_test)

# %%
# submission

submission_rf = pd.read_csv('./data/sample_submission.csv')
submission_rf['Body Mass (g)'] = y_pred_rf

# %%
# submission_rf.to_csv("./data/submission_rf.csv", index=False)

# %% [markdown]
# ## LightGBM

# %%
feature = X_train

lgbm = LGBMRegressor()

kfold = KFold(n_splits=5)

cv_rmse = [] # 각 cv회차의 rmse 점수를 계산하여 넣어줄 리스트를 생성. 이후 RMSE값의 평균을 구하기 위해 사용.
n_iter =0 # 반복 횟수 값을 초기 설정.

for train_idx, test_idx in kfold.split(feature):
    x_train, x_test = feature[train_idx], feature[test_idx]
    y_train, y_test = target[train_idx], target[test_idx]
    
    lgbm.fit(x_train, y_train)
    pred = lgbm.predict(x_test)
    n_iter += 1
    
    error = RMSE(y_test, pred)
    train_size = x_train.shape[0]
    test_size = x_test.shape[0]
    
    print('\n{0}번째 교차 검증 RMSE : {1}, 학습 데이터 크기 : {2}, 검증 데이터 크기 : {3}'.format(n_iter, error, train_size, test_size))
    
    cv_rmse.append(error)
    
print('\n ==> 이 방정식의 평균 에러(RMSE)는 {} 입니다.'.format(np.mean(cv_rmse)))
model_rmse['LightGBM'] = np.mean(cv_rmse)
# Out:
# 1번째 교차 검증 RMSE : 284.5517437081458, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 2번째 교차 검증 RMSE : 393.6305081387614, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 3번째 교차 검증 RMSE : 342.28669200748607, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 4번째 교차 검증 RMSE : 212.7963201829553, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 5번째 교차 검증 RMSE : 386.3067197134548, 학습 데이터 크기 : 92, 검증 데이터 크기 : 22
#
#  ==> 이 방정식의 평균 에러(RMSE)는 323.9143967501607 입니다.

# %% [markdown]
# ## XGBoost

# %%
feature = X_train

xgb = XGBRegressor()

kfold = KFold(n_splits=5)

cv_rmse = [] # 각 cv회차의 rmse 점수를 계산하여 넣어줄 리스트를 생성. 이후 RMSE값의 평균을 구하기 위해 사용.
n_iter =0 # 반복 횟수 값을 초기 설정.

for train_idx, test_idx in kfold.split(feature):
    x_train, x_test = feature[train_idx], feature[test_idx]
    y_train, y_test = target[train_idx], target[test_idx]
    
    xgb.fit(x_train, y_train)
    pred = xgb.predict(x_test)
    n_iter += 1
    
    error = RMSE(y_test, pred)
    train_size = x_train.shape[0]
    test_size = x_test.shape[0]
    
    print('\n{0}번째 교차 검증 RMSE : {1}, 학습 데이터 크기 : {2}, 검증 데이터 크기 : {3}'.format(n_iter, error, train_size, test_size))
    
    cv_rmse.append(error)
    
print('\n ==> 이 방정식의 평균 에러(RMSE)는 {} 입니다.'.format(np.mean(cv_rmse)))
model_rmse['XGBoost'] = np.mean(cv_rmse)
# Out:
# 1번째 교차 검증 RMSE : 350.9386960772004, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 2번째 교차 검증 RMSE : 426.6964219858497, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 3번째 교차 검증 RMSE : 369.5277695741565, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 4번째 교차 검증 RMSE : 359.54783367278975, 학습 데이터 크기 : 91, 검증 데이터 크기 : 23
#
# 5번째 교차 검증 RMSE : 396.0413033995716, 학습 데이터 크기 : 92, 검증 데이터 크기 : 22
#
#  ==> 이 방정식의 평균 에러(RMSE)는 380.5504049419136 입니다.

# %% [markdown]
# ## Ensemble

# %%
model_rmse
# Out:
# {'LinearRegression': 325.5934949337427,
#  'Lasso': 323.95317808326917,
#  'Ridge': 322.52346840258036,
#  'ElasticNet': 351.35173015767793,
#  'RandomForest': 341.39351814950453,
#  'LightGBM': 323.9143967501607,
#  'XGBoost': 380.5504049419136}

# %%
pd.DataFrame([model_rmse]).transpose().rename(columns={0:'RMSE'})
# Out:
#                     RMSE
# LinearRegression  325.59
# Lasso             323.95
# Ridge             322.52
# ElasticNet        351.35
# RandomForest      341.39
# LightGBM          323.91
# XGBoost           380.55

# %%
model_lr = LinearRegression().fit(X_train, target)
model_ridge = Ridge().fit(X_train, target)
model_lasso = Lasso().fit(X_train, target)
model_lgbm = LGBMRegressor().fit(X_train, target)
model_xgb = XGBRegressor().fit(X_train, target)
model_elastic = ElasticNet().fit(X_train, target)
model_rf = RandomForestRegressor().fit(X_train, target)

# %%
pred_lr = model_lr.predict(X_test)
pred_ridge = model_ridge.predict(X_test)
pred_lasso = model_lasso.predict(X_test)
pred_lgbm = model_lgbm.predict(X_test)
pred_xgb = model_xgb.predict(X_test)

# y_pred_ensemble = pred_lr*0.2 + pred_ridge*0.2 + pred_lasso*0.2 + pred_lgbm*0.2 + pred_xgb*0.2

pred_elastic = model_elastic.predict(X_test)
pred_rf = model_rf.predict(X_test)

y_pred_ensemble = pred_lr/7 + pred_ridge/7 + pred_lasso/7 + pred_lgbm/7 + pred_xgb/7 + pred_elastic/7 + pred_rf/7

# %%
# submission

submission_ensemble = pd.read_csv('./data/sample_submission.csv')
submission_ensemble['Body Mass (g)'] = y_pred_ensemble

# %%
# submission_ensemble.to_csv("./data/submission_ensemble.csv", index=False)
